# %% [markdown]
# # Deal Recommendation Engine - Liquidity Digital

# %%
import json 

# filename = "DFM-Mixpanel_All_Events.json"
filename = "DFM_Mixpanel_USer_Login.json" 

file = open(filename)
data = json.load(file)

# in the map, the users will be the key and the locations will be the value
users = []
locations = []


for user in data:
    locations.append(user['properties']['mp_country_code'])
    users.append(user['properties']['username'])
    
extracted_map = dict(zip(users, locations))
print(extracted_map)

print(json.dumps(data, indent=2, sort_keys=True))
# Out:
# {'neeraj@liquidity.digital': 'US', 'jitin@liquidity.digital': 'US', 'dfmn-testing@liquidity.digital': 'US', 'testinv@yopmail.com': 'IN', 'neerajrrep2@yopmail.com': 'IN', 'neerajrrep@yopmail.com': 'IN', 'neerajrrep1@yopmail.com': 'IN', 'deals@liquidity.capital': 'US', 'deals@liquidity.digital': 'US', 'neerajorg20@yopmail.com': 'IN', 'neerajorg201@yopmail.com': 'IN', 'alex@blackmanta.capital': 'RU', 'nikhil@liquidity.digital': 'IN', 'nkr@advantage-familyoffice.com': 'AE', 'john-o@yopmail.com': 'IN', 'kesav@yopmail.com': 'IN', 'jitin@Liquidity.digital': 'US', 'deals@yopmail.com': 'IN', 'origin2@yopmail.com': 'IN', 'investora1@yopmail.com': 'IN', 'rrepmsanoic@yopmail.com': 'IN', 'bobhead@yopmail.com': 'IN'}
# [
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e09f2caa2c7-01e9cef989c706-31677402-13c680-172e09f2cab7b5",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest2.liquidity.digital/admin/login",
#       "$device_id": "172e09f2caa2c7-01e9cef989c706-31677402-13c680-172e09f2cab7b5",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "i3r2whf3avkya931",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://demo.docusign.net/Signing/?insession=1&ti=8314e79db0604adfb85bf7e96e1c179e",
#       "$referring_domain": "demo.docusign.net",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593604205208,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593579000000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e09f2caa2c7-01e9cef989c706-31677402-13c680-172e09f2cab7b5",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/admin/login",
#       "$device_id": "172e09f2caa2c7-01e9cef989c706-31677402-13c680-172e09f2cab7b5",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "lasx2fj6eexhc8ty",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593754542185,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593729342000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "New Canaan",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "fdgqplo3b8xu1x79",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "Connecticut",
#       "$screen_height": 1003,
#       "$screen_width": 1504,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594343968693,
#       "username": "jitin@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594318767000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "New Canaan",
#       "$current_url": "https://jopis.liquidity.digital/rreps/login",
#       "$device_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "tosmdzoidyfofspp",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "Connecticut",
#       "$screen_height": 1003,
#       "$screen_width": 1504,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594415348690,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594390148000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "New Canaan",
#       "$current_url": "https://jopis.liquidity.digital/admin/login",
#       "$device_id": "173294482ce13a-0238d5fcc78cba-79657969-1704a0-173294482cf265",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "zmagctfayhgku0hh",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "Connecticut",
#       "$screen_height": 1003,
#       "$screen_width": 1504,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594415359068,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594390159000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1734486c7d251f-0e55ab4b7306a-317c0e5e-100200-1734486c7d357d",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/investor/login",
#       "$device_id": "1734486c7d251f-0e55ab4b7306a-317c0e5e-100200-1734486c7d357d",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "ahbdzy9tmqposcyh",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594582558697,
#       "username": "testinv@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594557358000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest2.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "8n60gi99bxe8mzwf",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593603591003,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593578390000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "a1dya371b0r1bg5m",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593603872940,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593578672000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "u210afcqulhjdx84",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://ldtest1.liquidity.digital/admin/login",
#       "$referring_domain": "ldtest1.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593604596042,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593579395000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "3xz0sw7luhbhobtd",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://ldtest1.liquidity.digital/admin/users",
#       "$referring_domain": "ldtest1.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593684503972,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593659303000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest2.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "0pm0q917k82xrt94",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://ldtest2.liquidity.digital/rreps/login",
#       "$referring_domain": "ldtest2.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593686818697,
#       "username": "neerajrrep2@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593661618000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest2.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "1oa318bj8sqpfd33",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://ldtest2.liquidity.digital/rreps/login",
#       "$referring_domain": "ldtest2.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593687002528,
#       "username": "neerajrrep2@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593661802000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "801nuh6u60dvjuah",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "http://www.yopmail.com/en/m.php?b=neerajrrep1&id=me_ZwNjAmNlZGZkAQHjZQNjAGDlZwN0Aj==",
#       "$referring_domain": "www.yopmail.com",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593695748000,
#       "username": "neerajrrep@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593670547000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "fdy10ppwc1h3p3yg",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "http://www.yopmail.com/en/m.php?b=neerajrrep1&id=me_ZwNjAmNlZGZkAQHjZQNjAGDlZwN0Aj==",
#       "$referring_domain": "www.yopmail.com",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593695750809,
#       "username": "neerajrrep@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593670550000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "2ssmc3hsez6kt2kv",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "http://www.yopmail.com/en/m.php?b=neerajrrep1&id=me_ZwNjAmNlZGZkAQHjZQNjAGDlZwN0Aj==",
#       "$referring_domain": "www.yopmail.com",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593695778048,
#       "username": "neerajrrep1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593670577000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://ldtest1.liquidity.digital/rreps/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "k1w9qcy8212mfh8o",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "http://www.yopmail.com/en/m.php?b=neerajrrep1&id=me_ZwNjAmNlZGZkAQHjZQNjAGDlZwN0Aj==",
#       "$referring_domain": "www.yopmail.com",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593695786225,
#       "username": "neerajrrep1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593670585000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://vijon.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "sh1hu3uzryckaom4",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593776023255,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593750823000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://jopis.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "pgse38bcechrapdp",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593776034880,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593750834000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://jopis.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "gi86gqyc1rb9n689",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://jopis.liquidity.digital/admin/login",
#       "$referring_domain": "jopis.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593968026284,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593942825000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://vijon.liquidity.digital/admin/login",
#       "$device_id": "1730a2cb05ea2-07474049dd0f59-31677402-13c680-1730a2cb06339",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "nilje2mkfa2twfdn",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593968033417,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593942833000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338fb6f219fe-0f2922b6e0c9148-15222b12-13c680-17338fb6f228dd",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Safari",
#       "$browser_version": 13,
#       "$city": "Coimbatore",
#       "$current_url": "https://jopis.liquidity.digital/admin/login",
#       "$device_id": "17338fb6f219fe-0f2922b6e0c9148-15222b12-13c680-17338fb6f228dd",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "la6t74u02ejt6gz4",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "Tamil Nadu",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594388882295,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594363682000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/rreps/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "6xlobx8nq8layeox",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594650637309,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594625432000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "qzxn4wm6vv9365aw",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594650919568,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594625715000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "2af0jlbuztakc9fa",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594651176181,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594625934000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/originator/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "2qq40e7pbeeabsd2",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594651241119,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594626036000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "0sh2vx0qazl2ax7a",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387424113,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362223000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/rreps/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "qf3jnpxffiuwumve",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387439863,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362238000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "12438vgalxai870g",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387455158,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362254000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "kv13se26hgp4qi5r",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387607120,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362405000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "pyyku8v8nc4m1qgo",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387619676,
#       "username": "deals@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362418000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "b9kl5og26iwaa5l8",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387623327,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362422000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "2ej83iquy66vr5i4",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387625714,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362424000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "43kpyhurclnagcwu",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387944059,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362742000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "17338e522393f6-0c8fcd502993e6-4353760-16e360-17338e5223a3e0",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "74kqssr5pe6ou1o4",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 1000,
#       "$screen_width": 1500,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594387960326,
#       "username": "deals@liquidity.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594362759000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Safari",
#       "$browser_version": 13.1,
#       "$city": "Coimbatore",
#       "$current_url": "https://vijon.liquidity.digital/admin/login",
#       "$device_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "jpyq8wers3m2bxuj",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "Tamil Nadu",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594227149636,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594201949000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Safari",
#       "$browser_version": 13.1,
#       "$city": "Coimbatore",
#       "$current_url": "https://jopis.liquidity.digital/admin/login",
#       "$device_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "d6tg7lwxpss19f1z",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "Tamil Nadu",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594398101976,
#       "username": "dfmn-testing@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1594372901000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Safari",
#       "$browser_version": 13.1,
#       "$city": "Coimbatore",
#       "$current_url": "https://ldtest1.liquidity.digital/admin/login",
#       "$device_id": "173100595663ad-011f10737aaffb-491b3601-384000-17310059567153b",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "f4fj4jntccvhzy1j",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "Tamil Nadu",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593701688205,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593676487000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/rreps/login",
#       "$device_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "n957uim0g8rwl8mj",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 900,
#       "$screen_width": 1600,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593878979149,
#       "username": "jitin@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593853779000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/rreps/login",
#       "$device_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "xuqccqwu0vkg5285",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 900,
#       "$screen_width": 1600,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593878995035,
#       "username": "jitin@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593853794000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Microsoft Edge",
#       "$browser_version": 83,
#       "$city": "Perth Amboy",
#       "$current_url": "https://syndicate.liquidity.digital/admin/login",
#       "$device_id": "1731a96ec5179d-0a29ee16e44845-79657967-15f900-1731a96ec52a46",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "5e6jm2yv11w1up4p",
#       "$lib_version": "2.38.0",
#       "$os": "Windows",
#       "$region": "New Jersey",
#       "$screen_height": 900,
#       "$screen_width": 1600,
#       "mp_country_code": "US",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593879081592,
#       "username": "jitin@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593853881000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr20.liquidity.digital/admin/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "9ucw934q9wyabi14",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593592449595,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593567249000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr20.liquidity.digital/admin/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "q8kv1mfbdo5nq9pt",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593592477871,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593567277000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr22.liquidity.digital/admin/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "hcgyms27r9t864cx",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593592496433,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593567296000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr20.liquidity.digital/admin/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "5cggl1hemyfrmvf5",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593594722604,
#       "username": "neeraj@liquidity.digital"
#     },
#     "sampling_factor": 1,
#     "time": 1593569522000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr20.liquidity.digital/originator/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "gl13wqkp01sey6jp",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "http://www.yopmail.com/en/m.php?b=neerajorg201&id=me_ZwNjAmNkZQxkZwZ1ZQNjZwp1Zmp3AN==",
#       "$referring_domain": "www.yopmail.com",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593594829352,
#       "username": "neerajorg20@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593569629000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "Delhi",
#       "$current_url": "https://dfmntr20.liquidity.digital/originator/login",
#       "$device_id": "172e9bdbeefa3-0dc1a7a8329424-31677402-13c680-172e9bdbef0791",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "slatoj5t3x27vd7c",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://dfmntr20.liquidity.digital/originator/login",
#       "$referring_domain": "dfmntr20.liquidity.digital",
#       "$region": "National Capital Territory of Delhi",
#       "$screen_height": 900,
#       "$screen_width": 1440,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593600374504,
#       "username": "neerajorg201@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593575174000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "St Petersburg",
#       "$current_url": "https://blackmanta.liquidity.digital/rreps/login",
#       "$device_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#       "$initial_referrer": "https://blackmanta.liquidity.digital/",
#       "$initial_referring_domain": "blackmanta.liquidity.digital",
#       "$insert_id": "fi5d8h6jkgzik8fm",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://blackmanta.liquidity.digital/",
#       "$referring_domain": "blackmanta.liquidity.digital",
#       "$region": "St.-Petersburg",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "RU",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594658462389,
#       "username": "alex@blackmanta.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594633262000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "St Petersburg",
#       "$current_url": "https://blackmanta.liquidity.digital/rreps/login",
#       "$device_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#       "$initial_referrer": "https://blackmanta.liquidity.digital/",
#       "$initial_referring_domain": "blackmanta.liquidity.digital",
#       "$insert_id": "2yo6uwqn0oek0i5q",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://blackmanta.liquidity.digital/",
#       "$referring_domain": "blackmanta.liquidity.digital",
#       "$region": "St.-Petersburg",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "RU",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594658468913,
#       "username": "alex@blackmanta.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594633268000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 83,
#       "$city": "St Petersburg",
#       "$current_url": "https://blackmanta.liquidity.digital/rreps/login",
#       "$device_id": "173490caeae1ff-0bd520be945b14-31617402-384000-173490caeaf910",
#       "$initial_referrer": "https://blackmanta.liquidity.digital/",
#       "$initial_referring_domain": "blackmanta.liquidity.digital",
#       "$insert_id": "gembg3n216rng711",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$referrer": "https://blackmanta.liquidity.digital/",
#       "$referring_domain": "blackmanta.liquidity.digital",
#       "$region": "St.-Petersburg",
#       "$screen_height": 1440,
#       "$screen_width": 2560,
#       "mp_country_code": "RU",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594658511685,
#       "username": "alex@blackmanta.capital"
#     },
#     "sampling_factor": 1,
#     "time": 1594633311000
#   },
#   {
# ...
#       "$current_url": "https://dfmntr22.liquidity.digital/rreps/login",
#       "$device_id": "172e05e55371eb-026fe8da6548b1-31607402-1ea000-172e05e5538b7a",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "xdfz71u3hf1fphx3",
#       "$lib_version": "2.38.0",
#       "$os": "Mac OS X",
#       "$region": "Karnataka",
#       "$screen_height": 1120,
#       "$screen_width": 1792,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1593595407438,
#       "username": "rrepmsanoic@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1593570206000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Arittapatti",
#       "$current_url": "http://localhost:9000/originator/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "ipy2l2ehf4q58pi9",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594279902636,
#       "username": "origin2@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594254702000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Arittapatti",
#       "$current_url": "http://localhost:9000/originator/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "b3zejimlz5vfhlh1",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594279922860,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594254722000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Arittapatti",
#       "$current_url": "http://localhost:9000/originator/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "x073caslr757hmpd",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594279927963,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594254727000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Arittapatti",
#       "$current_url": "http://localhost:9000/originator/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "x1nw8mmemytgd4rx",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594279930290,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594254730000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Arittapatti",
#       "$current_url": "http://localhost:9000/admin/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "pmv99ex8cx0tfqjn",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594279967931,
#       "username": "deals@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594254767000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "06k2k3tz4vbl6fb8",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594311263303,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594286062000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "phn3sqobt52f2nkf",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317495186,
#       "username": "investora1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292294000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "c8skhw6snqrojlea",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317499228,
#       "username": "investora1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292298000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "wnwd921wwq89wpx3",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317506225,
#       "username": "investora1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292305000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "vvq46hv6dvx3mh63",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317510147,
#       "username": "investora1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292309000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/investor/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "9392mzgznncbeung",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317778725,
#       "username": "investora1@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292578000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Madurai",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "osqcqzeithgpkcw8",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594317836875,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594292636000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "ax1mezi9hms6v4mj",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$referrer": "http://localhost:9000/rreps/login",
#       "$referring_domain": "localhost:9000",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594381828596,
#       "username": "bobhead@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594356628000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "mjw959qn52geh9kx",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$referrer": "http://localhost:9000/rreps/login",
#       "$referring_domain": "localhost:9000",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594381833195,
#       "username": "bobhead@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594356632000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/originator/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "b28f0fpuxui3ztp6",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594577420590,
#       "username": "origin2@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594552220000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/admin/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "mdt0fa34sk0s5hnp",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594577436934,
#       "username": "deals@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594552236000
#   },
#   {
#     "dataset": "$mixpanel",
#     "distinct_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#     "labels": [],
#     "name": "User Log in",
#     "properties": {
#       "$browser": "Chrome",
#       "$browser_version": 80,
#       "$city": "Coimbatore",
#       "$current_url": "http://localhost:9000/rreps/login",
#       "$device_id": "172ead9c1c62bb-0d3f69c7d10f39-317c0e5e-100200-172ead9c1c7743",
#       "$initial_referrer": "$direct",
#       "$initial_referring_domain": "$direct",
#       "$insert_id": "og4trc3hjwpku20k",
#       "$lib_version": "2.38.0",
#       "$os": "Linux",
#       "$region": "Tamil Nadu",
#       "$screen_height": 768,
#       "$screen_width": 1366,
#       "mp_country_code": "IN",
#       "mp_lib": "Segment: web",
#       "mp_processing_time_ms": 1594577464051,
#       "username": "kesav@yopmail.com"
#     },
#     "sampling_factor": 1,
#     "time": 1594552263000
#   }
# ]

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import sklearn
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
import time


# Configure Pandas display options
pd.set_option('mode.chained_assignment', None)
pd.options.display.width = 0
    
    
cols_to_use = [0, 1, 2, 3, 5]
df = pd.read_csv('mock_deal_database_1.csv', usecols=cols_to_use)
df_old = pd.read_csv('mock_deal_database_1.csv')


# df.dropna(how="all", inplace=True)
# df.drop_duplicates(inplace=True)


# ohe = OneHotEncoder(categories='auto', handle_unknown='ignore')
# ohe.fit_transform(df[['Industry Type', 'Issuance Type', 'Location']])

def normalize(amount_text):
    d = {
        'K': 1000,
        'M': 1000000,
        'B': 1000000000
    }
    if amount_text[-1] in d:
        # separate out the K, M, or B
        num, magnitude = amount_text[:-1], amount_text[-1]
        return int(float(num[1:]) * d[magnitude])
    else:
        return float(amount_text[1:])


# scaler = MinMaxScaler()
# df['Target Raise'] = scaler.fit_transform(df[['Target Raise']])
process = 1.7

# %% [markdown]
# ## Deal List / Before DRE

# %%
num_rows = df_old.shape[0]
print("# Deals: " + str(num_rows))
df_old
# Out:
# # Deals: 2999
#                  Deals     Industry Type     Issuance Type Target Raise  \
# 0         EFF Ventures       Agriculture               STO         $10M
# 1          YAD Capital    Private Equity            Equity          $5M
# 2             Intercom          Software  Convertible Note        $600K
# 3                 Komp             Other             Other        $500K
# 4              CarbonV        Healthcare            Equity          $2M
# ...                ...               ...               ...          ...
# 2994     MajorWeb, LLC        Healthcare               STO          $9M
# 2995      Makad Energy  Consumer Staples  Convertible Note          $2M
# 2996  Makana Solutions        Healthcare               STO         $11M
# 2997      Makani Power            Energy              Debt          $3M
# 2998            OXILIA         Utilities            Equity         $15M
#
#      Amount Raised        Location
# 0             $30M         Denmark
# 1              $5M          Israel
# 2            $250K         Belgium
# 3              $1M        Thailand
# 4            $500K        Thailand
# ...            ...             ...
# 2994          $93M   United States
# 2995          $22M  United Kingdom
# 2996           $5M        Malaysia
# 2997          $83M          Canada
# 2998          $18M        Malaysia
#
# [2999 rows x 6 columns]

# %%
## Data Pipeline

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neighbors import NearestNeighbors

class Columns(BaseEstimator, TransformerMixin):
    def __init__(self, names=None):
        self.names = names

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X):
        return X[self.names]

numeric = ["Target Raise"]
categorical = ["Industry Type", "Issuance Type", "Location"]

model=NearestNeighbors(metric="euclidean",algorithm="brute", n_neighbors=2, n_jobs=1)

pipe = Pipeline([
    ("features", FeatureUnion([
        ('numeric', make_pipeline(Columns(names=numeric),StandardScaler())),
        ('categorical', make_pipeline(Columns(names=categorical),OneHotEncoder(sparse=False)))
    ])),
    ('model', model)
])

# %%
# ## Take in investor input for preferences:
print("Please Enter Your Deal Preferences Below.")
industry_pref = input("Industry: ").capitalize()
issuance_pref = input("Issuance Type: ").capitalize()
investment_amt = input("Ideal Investment Amount ($1M, $100k, etc): ").upper()
location_pref = input("Location: ").capitalize()

name = "INVESTOR"

new_row = {"Deals": name, "Industry Type": industry_pref, "Issuance Type": issuance_pref, "Target Raise": investment_amt, "Location": location_pref}
df = df.append(new_row, ignore_index=True)
df_old = df_old.append(new_row, ignore_index=True)
test_index = len(df) - 1
# Out:
# Please Enter Your Deal Preferences Below.
# Industry: healthcare
# Issuance Type: equity
# Ideal Investment Amount ($1M, $100k, etc): $1m
# Location: singapore

# %% [markdown]
# ## Pre-Processing Input

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler

df['Target Raise'] = df['Target Raise'].apply(lambda x: (normalize(x) if x != "n/a" else x))

X = df

currency_type = "$"

## TRANSFORMER METHOD
column_trans = make_column_transformer(
(OneHotEncoder(categories='auto'), ['Industry Type', 'Issuance Type', 'Location']),
(StandardScaler(), ['Target Raise']))


## This is what the data looks like going into the model
#print(column_trans.fit_transform(X).toarray())
T = column_trans.fit_transform(X)

# %% [markdown]
# ## Model Fitting

# %%
nbrs = NearestNeighbors(metric = 'euclidean', n_neighbors=10, algorithm = 'auto').fit(T.toarray())
deal_index = test_index
distances, indices = nbrs.kneighbors([T.toarray()[deal_index]])

# %% [markdown]
# ## Output

# %%
from numerize import numerize

deals = []
industries = []
issuance_types = []
amount_raised = []
locations = []
target_raises = []
euclids = []

for i in range(len(indices[0])):
    ind = indices[0][i]
    deals.append(df["Deals"][ind])
    industries.append(df["Industry Type"][ind])
    issuance_types.append(df['Issuance Type'][ind])
    amount_raised.append(df_old['Amount Raised'][ind])
    locations.append(df['Location'][ind])
    target_raises.append(df["Target Raise"][ind])
    euclids.append(str(distances[0][i]))


output_df = pd.DataFrame({'Deals': deals,
                          'Industry': industries,
                          'Issuance Type': issuance_types,
                          'Target Raise': target_raises,
                          'Amount Raised': amount_raised,
                          'Location': locations,
                         'Match': euclids})

def similar(distance):
    to_return = (1 / (1 + float(distance))) * 100
    return str(round(to_return, 3)) + "%"

def match(distance):
    to_return = (1 / (1 + float(distance))) * 100
    rounded = round(to_return, 3)
    if rounded <= 42:
        return "LOW"
    elif rounded >= 43 and rounded < 80:
        return "MEDIUM"
    else:
        return "HIGH"

output_df['Target Raise'] = output_df['Target Raise'].apply(lambda x: currency_type + (numerize.numerize(x) if x != "n/a" else x))
output_df['Match'] = output_df['Match'].apply(lambda x: match(x) if x != "n/a" else x)
output_df = output_df.drop(0)
# df_old = df_old.drop(test_index)

print("Deal Recommendations for you, based on your preferences: \n" )
time.sleep(process + 1.5)
output_df
# Out:
# Deal Recommendations for you, based on your preferences:
#                       Deals    Industry Issuance Type Target Raise  \
# 1            Dealer Inspire  Healthcare        Equity        $604K
# 2             Deep Identity  Healthcare        Equity        $367K
# 3                    Jobdoh  Healthcare        Equity          $7M
# 4                GymForLess  Healthcare        Equity          $1M
# 5        CertificationPoint  Healthcare        Equity        $982K
# 6                    ams AG  Healthcare        Equity        $966K
# 7  Delta Plant Technologies  Healthcare        Equity        $942K
# 8                   Certona  Healthcare        Equity        $871K
# 9                   BringIt  Healthcare        Equity        $868K
#
#   Amount Raised     Location   Match
# 1           $1M    Singapore    HIGH
# 2          $10M    Singapore    HIGH
# 3           $3M    Singapore  MEDIUM
# 4           $9M       Mexico     LOW
# 5           $6M     Thailand     LOW
# 6           $3M      Belgium     LOW
# 7           $6M  Afghanistan     LOW
# 8           $6M      Denmark     LOW
# 9           $2M  New Zealand     LOW

# %% [markdown]
# ## More Deals Like This....

# %%
DEAL_TO_FIND_OTHERS = input("More Deals Like: ").capitalize()
new_deal_index = df[df['Deals'] == DEAL_TO_FIND_OTHERS].index.values.astype(int)[0]

nbrs_clone_deal = NearestNeighbors(metric = 'euclidean', n_neighbors=10, algorithm = 'auto').fit(T.toarray())
new_distances, new_indices = nbrs_clone_deal.kneighbors([T.toarray()[new_deal_index]])
# Out:
# More Deals Like: Jobdoh

# %%
new_distances, new_indices = nbrs.kneighbors([T.toarray()[new_deal_index]])

deals = []
industries = []
issuance_types = []
amount_raised = []
locations = []
target_raises = []
euclids = []

for i in range(len(indices[0])):
    ind = new_indices[0][i]
    deals.append(df["Deals"][ind])
    industries.append(df["Industry Type"][ind])
    issuance_types.append(df['Issuance Type'][ind])
    amount_raised.append(df_old['Amount Raised'][ind])
    locations.append(df['Location'][ind])
    target_raises.append(df["Target Raise"][ind])
    euclids.append(str(new_distances[0][i]))


new_output_df = pd.DataFrame({'Deals': deals,
                          'Industry': industries,
                          'Issuance Type': issuance_types,
                          'Target Raise': target_raises,
                          'Amount Raised': amount_raised,
                          'Location': locations,
                         'Similarity': euclids})


new_output_df['Target Raise'] = new_output_df['Target Raise'].apply(lambda x: currency_type + (numerize.numerize(x) if x != "n/a" else x))
new_output_df['Similarity'] = new_output_df['Similarity'].apply(lambda x: similar(x) if x != "n/a" else x)
new_output_df = new_output_df.drop(0)

print("Deal Recommendations Processing for " + df["Deals"][new_deal_index] + "... \n" )
time.sleep(process)
print("Here are some deals we think you'd like, based on your interest in " + df["Deals"][new_deal_index] + ":")
new_output_df
# Out:
# Deal Recommendations Processing for Jobdoh...
#
# Here are some deals we think you'd like, based on your interest in Jobdoh:
#                                       Deals    Industry Issuance Type  \
# 1                                  INVESTOR  Healthcare        Equity
# 2                            Dealer Inspire  Healthcare        Equity
# 3                             Deep Identity  Healthcare        Equity
# 4                                  ITS KOOL  Healthcare        Equity
# 5                                  Joberate  Healthcare        Equity
# 6                                     itzat   Utilities        Equity
# 7           FaceCake Marketing Technologies  Healthcare        Equity
# 8                                 EyeVerify  Healthcare          Debt
# 9  Jiangsu Shunda Semiconductor Development  Healthcare        Equity
#
#   Target Raise Amount Raised     Location Similarity
# 1          $1M           NaN    Singapore    44.601%
# 2        $604K           $1M    Singapore    43.027%
# 3        $367K          $10M    Singapore    42.138%
# 4          $7M          $76M        India    41.421%
# 5          $7M          $69M      Ireland    41.421%
# 6          $7M          $28M    Singapore    41.421%
# 7          $7M          $27M  Afghanistan    41.421%
# 8          $7M          $96M    Singapore    41.421%
# 9          $7M          $43M      Belgium    41.421%
